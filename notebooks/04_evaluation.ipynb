# %% [markdown]
# # 04_evaluation

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'src').exists() else Path.cwd().resolve().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
print('PROJECT_ROOT =', PROJECT_ROOT)

# %%
from src.iris_project.preprocessing import list_images
from src.iris_project.model import IrisSegmentationModel

model = IrisSegmentationModel()
for p in list_images(PROJECT_ROOT / 'data')[:5]:
    print(p.name, model.predict(p))
