# %% [markdown]
# # 01_data_audit

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'src').exists() else Path.cwd().resolve().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
print('PROJECT_ROOT =', PROJECT_ROOT)

# %%
from src.iris_project.data_audit import audit_dataset, infer_task

report = audit_dataset(PROJECT_ROOT / 'data')
print(report)
print('Inferred task:', infer_task(report.mat_summaries))
